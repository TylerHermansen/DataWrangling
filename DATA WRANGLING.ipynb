# %%
import numpy as np
import pandas as pd
% matplotlib inline
# Out:
# UsageError: Line magic function `%` not found.

# %%
import numpy as np
import pandas as pd

# %%
matplotlib inline

# %%
df = pd.read_csv('Air_Traffic_Cargo_Statistics.csv')

# %%
df.shape
# Out:
# (35599, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35599 entries, 0 to 35598
# Data columns (total 12 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Activity Period              35599 non-null  int64
#  1   Operating Airline            35599 non-null  object
#  2   Operating Airline IATA Code  35545 non-null  object
#  3   Published Airline            35599 non-null  object
#  4   Published Airline IATA Code  35545 non-null  object
#  5   GEO Summary                  35599 non-null  object
#  6   GEO Region                   35599 non-null  object
#  7   Activity Type Code           35599 non-null  object
#  8   Cargo Type Code              35599 non-null  object
#  9   Cargo Aircraft Type          35599 non-null  object
#  10  Cargo Weight LBS             35599 non-null  int64
#  11  Cargo Metric TONS            35599 non-null  float64
# dtypes: float64(1), int64(2), object(9)
# ...

# %%
df.head()
# Out:
#    Activity Period Operating Airline Operating Airline IATA Code  \
# 0           200507           ABX Air                          GB
# 1           200507           ABX Air                          GB
# 2           200507      ATA Airlines                          TZ
# 3           200507      ATA Airlines                          TZ
# 4           200507      ATA Airlines                          TZ
#
#   Published Airline Published Airline IATA Code GEO Summary GEO Region  \
# 0           ABX Air                          GB    Domestic         US
# 1           ABX Air                          GB    Domestic         US
# 2      ATA Airlines                          TZ    Domestic         US
# 3      ATA Airlines                          TZ    Domestic         US
# 4      ATA Airlines                          TZ    Domestic         US
#
#   Activity Type Code Cargo Type Code Cargo Aircraft Type  Cargo Weight LBS  \
# ...

# %%
df.tail()
# Out:
#        Activity Period Operating Airline Operating Airline IATA Code  \
# 35594           202109   United Airlines                          UA
# 35595           202109   United Airlines                          UA
# 35596           202109   United Airlines                          UA
# 35597           202109   United Airlines                          UA
# 35598           202109   United Airlines                          UA
#
#       Published Airline Published Airline IATA Code    GEO Summary  \
# 35594   United Airlines                          UA  International
# 35595   United Airlines                          UA  International
# 35596   United Airlines                          UA  International
# 35597   United Airlines                          UA  International
# 35598   United Airlines                          UA  International
#
#         GEO Region Activity Type Code Cargo Type Code Cargo Aircraft Type  \
# ...

# %%
df.describe()
# Out:
#        Activity Period  Cargo Weight LBS  Cargo Metric TONS
# count     35599.000000      3.559900e+04       35599.000000
# mean     201311.369449      4.799115e+05         217.687856
# std         473.480500      9.509778e+05         431.363548
# min      200507.000000      1.000000e+00           0.000000
# 25%      200905.000000      1.839650e+04           8.344500
# 50%      201307.000000      1.329570e+05          60.309000
# 75%      201709.000000      5.469705e+05         248.106000
# max      202109.000000      2.381234e+07       10801.278000

# %%
df['Cargo Weight LBS'].min()
# Out:
# 1

# %%
df['Cargo Weight LBS'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df['Cargo Weight LBS'].plot()
# Out:
# <AxesSubplot:>

# %%
Operating_Airline.sort_index()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [13], in <cell line: 1>()
# ----> 1 Operating_Airline.sort_index()
#
# NameError: name 'Operating_Airline' is not defined

# %%
airline = df['Operating Airline']

# %%
airline.sort_index()
# Out:
# 0                ABX Air
# 1                ABX Air
# 2           ATA Airlines
# 3           ATA Airlines
# 4           ATA Airlines
#               ...
# 35594    United Airlines
# 35595    United Airlines
# 35596    United Airlines
# 35597    United Airlines
# 35598    United Airlines
# Name: Operating Airline, Length: 35599, dtype: object

# %%
weight = df['Cargo Weight LBS']

# %%
weight.mean()
# Out:
# 479911.5099300542

# %%
df[-2:]
# Out:
#        Activity Period Operating Airline Operating Airline IATA Code  \
# 35597           202109   United Airlines                          UA
# 35598           202109   United Airlines                          UA
#
#       Published Airline Published Airline IATA Code    GEO Summary  \
# 35597   United Airlines                          UA  International
# 35598   United Airlines                          UA  International
#
#         GEO Region Activity Type Code Cargo Type Code Cargo Aircraft Type  \
# 35597  Middle East           Enplaned         Express           Passenger
# 35598  Middle East           Enplaned            Mail           Passenger
#
#        Cargo Weight LBS  Cargo Metric TONS
# 35597             14432              6.546
# 35598             40440             18.344

# %%
df.loc[:11]
# Out:
#     Activity Period Operating Airline Operating Airline IATA Code  \
# 0            200507           ABX Air                          GB
# 1            200507           ABX Air                          GB
# 2            200507      ATA Airlines                          TZ
# 3            200507      ATA Airlines                          TZ
# 4            200507      ATA Airlines                          TZ
# 5            200507      ATA Airlines                          TZ
# 6            200507        Air Canada                          AC
# 7            200507        Air Canada                          AC
# 8            200507        Air Canada                          AC
# 9            200507        Air Canada                          AC
# 10           200507        Air Canada                          AC
# 11           200507        Air Canada                          AC
#
#    Published Airline Published Airline IATA Code    GEO Summary GEO Region  \
# ...

# %%
df.iloc[:-2]
# Out:
#        Activity Period Operating Airline Operating Airline IATA Code  \
# 0               200507           ABX Air                          GB
# 1               200507           ABX Air                          GB
# 2               200507      ATA Airlines                          TZ
# 3               200507      ATA Airlines                          TZ
# 4               200507      ATA Airlines                          TZ
# ...                ...               ...                         ...
# 35592           202109   United Airlines                          UA
# 35593           202109   United Airlines                          UA
# 35594           202109   United Airlines                          UA
# 35595           202109   United Airlines                          UA
# 35596           202109   United Airlines                          UA
#
#       Published Airline Published Airline IATA Code    GEO Summary  \
# 0               ABX Air                          GB       Domestic
# ...

# %%
df.loc[:, ['Cargo Weight LBS']]
# Out:
#        Cargo Weight LBS
# 0                 45423
# 1                106869
# 2                 55427
# 3                 50278
# 4                 74183
# ...                 ...
# 35594              9739
# 35595             13543
# 35596            395220
# 35597             14432
# 35598             40440
#
# [35599 rows x 1 columns]

# %%
df[df['Cargo Weight LBS'] >= weight.mean()]
# Out:
#        Activity Period   Operating Airline Operating Airline IATA Code  \
# 12              200507           Air China                          CA
# 32              200507  All Nippon Airways                          NH
# 36              200507   American Airlines                          AA
# 38              200507   American Airlines                          AA
# 39              200507   American Airlines                          AA
# ...                ...                 ...                         ...
# 35575           202109     United Airlines                          UA
# 35578           202109     United Airlines                          UA
# 35581           202109     United Airlines                          UA
# 35584           202109     United Airlines                          UA
# 35593           202109     United Airlines                          UA
#
#         Published Airline Published Airline IATA Code    GEO Summary  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35599 entries, 0 to 35598
# Data columns (total 12 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Activity Period              35599 non-null  int64
#  1   Operating Airline            35599 non-null  object
#  2   Operating Airline IATA Code  35545 non-null  object
#  3   Published Airline            35599 non-null  object
#  4   Published Airline IATA Code  35545 non-null  object
#  5   GEO Summary                  35599 non-null  object
#  6   GEO Region                   35599 non-null  object
#  7   Activity Type Code           35599 non-null  object
#  8   Cargo Type Code              35599 non-null  object
#  9   Cargo Aircraft Type          35599 non-null  object
#  10  Cargo Weight LBS             35599 non-null  int64
#  11  Cargo Metric TONS            35599 non-null  float64
# dtypes: float64(1), int64(2), object(9)
# ...

# %%
df[['Operating Airline IATA Code','Published Airline IATA Code']].head(50)
# Out:
#    Operating Airline IATA Code Published Airline IATA Code
# 0                           GB                          GB
# 1                           GB                          GB
# 2                           TZ                          TZ
# 3                           TZ                          TZ
# 4                           TZ                          TZ
# 5                           TZ                          TZ
# 6                           AC                          AC
# 7                           AC                          AC
# 8                           AC                          AC
# 9                           AC                          AC
# 10                          AC                          AC
# 11                          AC                          AC
# 12                          CA                          CA
# 13                          CA                          CA
# 14                          AF                          AF
# ...

# %%
df[df.isnull().any(axis=1)]
# Out:
#        Activity Period                                 Operating Airline  \
# 3874            200703                                         Focus Air
# 4060            200704                                         Focus Air
# 9575            200909                                        E.A.G.L.E.
# 11152           201005                                     Swissport USA
# 13964           201109                 Air Transport International, LLC.
# 13965           201109                 Air Transport International, LLC.
# 14125           201110                                    ASTAR USA, LLC
# 14126           201110                                    ASTAR USA, LLC
# 14148           201110                 Air Transport International, LLC.
# 14149           201110                 Air Transport International, LLC.
# 14302           201111                                    ASTAR USA, LLC
# 14303           201111                                    ASTAR USA, LLC
# ...

# %%
df.drop(columns='Published Airline IATA Code', inplace=True)

# %%
df.drop(columns='Operating Airline IATA Code', inplace=True)

# %%
df
# Out:
#        Activity Period Operating Airline Published Airline    GEO Summary  \
# 0               200507           ABX Air           ABX Air       Domestic
# 1               200507           ABX Air           ABX Air       Domestic
# 2               200507      ATA Airlines      ATA Airlines       Domestic
# 3               200507      ATA Airlines      ATA Airlines       Domestic
# 4               200507      ATA Airlines      ATA Airlines       Domestic
# ...                ...               ...               ...            ...
# 35594           202109   United Airlines   United Airlines  International
# 35595           202109   United Airlines   United Airlines  International
# 35596           202109   United Airlines   United Airlines  International
# 35597           202109   United Airlines   United Airlines  International
# 35598           202109   United Airlines   United Airlines  International
#
#         GEO Region Activity Type Code Cargo Type Code Cargo Aircraft Type  \
# ...

# %%
weight.plot.box()
# Out:
# <AxesSubplot:>

# %%
cargo = df['Cargo Metric TONS']

# %%
cargo.plot.box()
# Out:
# <AxesSubplot:>

# %%
df.plot.scatter(x='Cargo Weight LBS' , y='Cargo Metric TONS')
# Out:
# <AxesSubplot:xlabel='Cargo Weight LBS', ylabel='Cargo Metric TONS'>

# %%
df.duplicated().any()
# Out:
# False

# %%
df['Operating Airline'].drop_duplicates()
# Out:
# 0                                                 ABX Air
# 2                                            ATA Airlines
# 6                                              Air Canada
# 12                                              Air China
# 14                                             Air France
#                                ...
# 30820                                    TAP Air Portugal
# 31616                           Norwegian Air Shuttle ASA
# 32533                   Air Transport International, Inc.
# 33968                                       Qatar Airways
# 35168    Philippine Airline, Inc. (INACTIVE - DO NOT USE)
# Name: Operating Airline, Length: 97, dtype: object

# %%
df['Operating Airline'].value_counts()
# Out:
# United Airlines                     3539
# United Airlines - Pre 07/01/2013    2503
# Korean Air Lines                    1519
# Alaska Airlines                     1402
# China Airlines                      1297
#                                     ...
# Virgin America                         5
# Focus Air                              2
# Air Canada Jazz                        2
# E.A.G.L.E.                             1
# Atlantic Southeast Airlines            1
# Name: Operating Airline, Length: 97, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35599 entries, 0 to 35598
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Activity Period      35599 non-null  int64
#  1   Operating Airline    35599 non-null  object
#  2   Published Airline    35599 non-null  object
#  3   GEO Summary          35599 non-null  object
#  4   GEO Region           35599 non-null  object
#  5   Activity Type Code   35599 non-null  object
#  6   Cargo Type Code      35599 non-null  object
#  7   Cargo Aircraft Type  35599 non-null  object
#  8   Cargo Weight LBS     35599 non-null  int64
#  9   Cargo Metric TONS    35599 non-null  float64
# dtypes: float64(1), int64(2), object(7)
# memory usage: 2.7+ MB

# %%
air = df.groupby('Operating Airline')[['Cargo Weight LBS', 'Cargo Metric TONS']]

# %%
air.sum()
# Out:
#                           Cargo Weight LBS  Cargo Metric TONS
# Operating Airline
# ABX Air                          465356824         211085.857
# ASTAR USA, LLC                     2450985           1111.766
# ATA Airlines                       3648696           1655.046
# Aer Lingus, Ltd.                  34324942          15569.787
# Aeromexico                            3477              1.578
# ...                                    ...                ...
# United Parcel Service CO           2586865           1173.401
# Virgin America                       66547             30.185
# Virgin Atlantic                  207374487          94065.072
# WOW Air                            3785632           1717.159
# World Airways                     54626729          24778.683
#
# [97 rows x 2 columns]

# %%
pf = df.groupby(['Cargo Aircraft Type','GEO Summary'])['Cargo Weight LBS'].mean()

# %%
pf.unstack()
# Out:
# GEO Summary              Domestic  International
# Cargo Aircraft Type
# Combi                         NaN  618954.091765
# Freighter            1.855385e+06  691362.902072
# Passenger            4.401987e+05  339445.442742

# %%
pf
# Out:
# Cargo Aircraft Type  GEO Summary
# Combi                International    6.189541e+05
# Freighter            Domestic         1.855385e+06
#                      International    6.913629e+05
# Passenger            Domestic         4.401987e+05
#                      International    3.394454e+05
# Name: Cargo Weight LBS, dtype: float64
